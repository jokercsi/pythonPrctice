# %% [markdown]
# #### class ClassName:
#     def calculateDate():
#         year = int(input('년도를 입력하세요:'))
#         month = int(input('월을 입력하세요:'))
#         day = int(input('일을 입력하세요:'))
#
#         total_days = 0
#
#         for i in range(1, year):
#             if i % 400 == 0:
#                 total_days = total_days + 366
#             elif i % 100 == 0:
#                 total_days = total_days + 365
#             elif i % 4 == 0:
#                 total_days = total_days + 366
#             else:
#                 total_days = total_days + 365
#
#         y_m_days = [0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
#         for i in range(1, month):
#             total_days = total_days + y_m_days[i]
#
#         if month >= 3:
#             if year % 400 == 0:
#                 total_days = total_days + 1
#             elif i % 100 == 0:
#                 total_days = total_days + 0
#             elif i % 4 == 0:
#                 total_days = total_days + 1
#             else:
#                 total_days = total_days + 0
#
#         total_days = total_days + day
#
#         if total_days % 7 == 1:
#             print('%s년 %s월 %s일은' % (year, month, day), '월요일 입니다')
#         elif total_days % 7 == 2:
#             print('%s년 %s월 %s일은' % (year, month, day), '화요일 입니다')
#         elif total_days % 7 == 3:
#             print('%s년 %s월 %s일은' % (year, month, day), '수요일 입니다')
#         elif total_days % 7 == 4:
#             print('%s년 %s월 %s일은' % (year, month, day), '목요일 입니다')
#         elif total_days % 7 == 5:
#             print('%s년 %s월 %s일은' % (year, month, day), '금요일 입니다')
#         elif total_days % 7 == 6:
#             print('%s년 %s월 %s일은' % (year, month, day), '토요일 입니다')
#         else :
#             print('%s년 %s월 %s일은' % (year, month, day), '일요일 입니다')
#
#
# call = ClassName.calculateDate()

# %%
class total_days:
    def total_days():
        year = int(input('년도를 입력하세요:'))
        month = int(input('월을 입력하세요:'))
        day = int(input('일을 입력하세요:'))

        total_days = 0

        for i in range(1, year):
            if i % 400 == 0:
                total_days = total_days + 366
            elif i % 100 == 0:
                total_days = total_days + 365
            elif i % 4 == 0:
                total_days = total_days + 366
            else:
                total_days = total_days + 365

        y_m_days = [0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        for i in range(1, month):
            total_days = total_days + y_m_days[i]

        if month >= 3:
            if year % 400 == 0:
                total_days = total_days + 1
            elif i % 100 == 0:
                total_days = total_days + 0
            elif i % 4 == 0:
                total_days = total_days + 1
            else:
                total_days = total_days + 0

        total_days = total_days + day

        if total_days % 7 == 1:
            print('%s년 %s월 %s일은' % (year, month, day), '월요일 입니다')
        elif total_days % 7 == 2:
            print('%s년 %s월 %s일은' % (year, month, day), '화요일 입니다')
        elif total_days % 7 == 3:
            print('%s년 %s월 %s일은' % (year, month, day), '수요일 입니다')
        elif total_days % 7 == 4:
            print('%s년 %s월 %s일은' % (year, month, day), '목요일 입니다')
        elif total_days % 7 == 5:
            print('%s년 %s월 %s일은' % (year, month, day), '금요일 입니다')
        elif total_days % 7 == 6:
            print('%s년 %s월 %s일은' % (year, month, day), '토요일 입니다')
        else :
            print('%s년 %s월 %s일은' % (year, month, day), '일요일 입니다')

total_days.total_days()
# Out:
# 년도를 입력하세요:1
# 월을 입력하세요:2
# 일을 입력하세요:3
# 1년 2월 3일은 토요일 입니다
